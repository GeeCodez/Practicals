# %%
example_string="Hello I am a string"

# %%
a="Yaw"
print(a)
# Out:
# Yaw

# %%
print(example_string.upper())
# Out:
# HELLO I AM A STRING

# %%
print(example_string.lower())
# Out:
# hello i am a string

# %%
new_string = "        " + example_string
print(new_string)
# Out:
#         Hello I am a string                Hello I am a string

# %%
print(new_string.strip())
# Out:
# Hello I am a string                Hello I am a string

# %%
print(example_string.replace("Hello","Hi,9"))
# Out:
# Hi,9 I am a string                Hi,9 I am a string

# %%
print(example_string.split(" "))
# Out:
# ['Hello', 'I', 'am', 'a', 'string', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Hello', 'I', 'am', 'a', 'string', '', '', '', '', '', '', '', '']

# %%
new_string1="Hello I am the second version of a new string"
parts = new_string1.split(" ")
print(parts[0])
# Out:
# Hello

# %%
print(new_string1.find("second",3))
# Out:
# 15
