# %%
import pandas as pd
data=pd.read_csv(r"api_development_tools.csv")

data.head(5) #gets the first 5 elements in the data
data.tail(3) #shows the last 3 elements in the data
data.info() 
data.describe()
data.shape() #shows the columns and the rows in the data.

# %%
import requests
from bs4 import BeautifulSoup
